# %%
## arithmetic operaions
a=10
b=7
result=a+b
print(result)

div=a/b
print(div)

floor_div = a//b
print(floor_div)

expon_result = a**b
print(expon_result)
# Out:
# 17
# 1.4285714285714286
# 1
# 10000000

# %%
## comparision operator ==
a=10
b=10

a==b
# Out:
# True
