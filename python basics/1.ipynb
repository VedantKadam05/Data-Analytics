# %%
## this is single line comment

# %%
## case sensitivity python is case sensitive
name = "vedant"
Name = "kadam"

print(name)
print(Name)
# Out:
# vedant
# kadam

# %%
## Indentaion
## python uses identation to define block of code. consistent use of spaces (commonly 4) or a tab is required

age=32
if age>30:
    print("eligible to become president")
else:
    print("you cannot become president")
# Out:
# eligible to become president

# %%
##line continuation
total = 4+4+7+2+9+8+\
6+3+9

print(total)
# Out:
# 52

# %%
## multiple statements on single line
x=7;y=9; z=x+y
print(z)
# Out:
# 16

# %%
## semantics in python
##variable assignment
age=89  ## we do not assign the data type in python kernel decides it in run time here age is integer
name="raghav chaddha" ## here name is string

print(age)
print(name)

type(age)
# Out:
# 89
# raghav chaddha
# int

# %%
type(name)
# Out:
# str

# %%
#example of identation
if True:
    print("correct Identaion")

    if False:
        print("this wont print")
    print("will print")    

print("outside the if block")
# Out:
# correct Identaion
# will print
# outside the if block
